# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Dataset_626.csv")
df=pd.DataFrame(df)

# %%
column_means=df.mean()
cleanerdf=df.fillna(column_means)

# where datapoints are NA or null they are replaced by the mean of the atrribute

# %%
corr=cleanerdf.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# visuallising the correlation of the different variables
# Out:
# <style  type="text/css" >
#     #T_908ab67c_dcd3_11eb_b1b8_6a6d787fe2barow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_908ab67c_dcd3_11eb_b1b8_6a6d787fe2barow0_col1 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_908ab67c_dcd3_11eb_b1b8_6a6d787fe2barow0_col2 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_908ab67c_dcd3_11eb_b1b8_6a6d787fe2barow0_col3 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_908ab67c_dcd3_11eb_b1b8_6a6d787fe2barow0_col4 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_908ab67c_dcd3_11eb_b1b8_6a6d787fe2barow0_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_908ab67c_dcd3_11eb_b1b8_6a6d787fe2barow0_col6 {
#             background-color:  #779af7;
#             color:  #000000;
# ...

# %%
cleanerdf.isnull().any()
#checking to ensure that there are no more null datapoints
# Out:
# FIPS                                           False
# State                                          False
# County                                         False
# Cases by county population                     False
# % fatality of cases                            False
# deaths by county                               False
# % of total cases                               False
# % of total deaths                              False
# % of total cases/Pop                           False
# % of total deaths/Pop                          False
# % Fair or Poor Health                          False
# Average Number of Physically Unhealthy Days    False
# Average Number of Mentally Unhealthy Days      False
# % Smokers                                      False
# % Adults with Obesity                          False
# % Physically Inactive                          False
# % Excessive Drinking                           False
# % Uninsured                                    False
# ...

# %%
xcolumns=["% Children in Poverty"]
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
#adding the attribute with the highest correlation

# %%
def get_stats():
  
    results=sm.WLS(y,x).fit()
    print(results.summary())
get_stats()

# analysing the dataset
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.754
# Model:                            WLS   Adj. R-squared (uncentered):              0.754
# Method:                 Least Squares   F-statistic:                              9627.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:38   Log-Likelihood:                          2369.2
# No. Observations:                3142   AIC:                                     -4736.
# Df Residuals:                    3141   BIC:                                     -4730.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("Cases by county population")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()

#starting the forwardstep regression
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.831
# Model:                            WLS   Adj. R-squared (uncentered):              0.831
# Method:                 Least Squares   F-statistic:                              7722.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:38   Log-Likelihood:                          2959.4
# No. Observations:                3142   AIC:                                     -5915.
# Df Residuals:                    3140   BIC:                                     -5903.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("Median Household Income")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.836
# Model:                            WLS   Adj. R-squared (uncentered):              0.836
# Method:                 Least Squares   F-statistic:                              5329.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:38   Log-Likelihood:                          3005.0
# No. Observations:                3142   AIC:                                     -6004.
# Df Residuals:                    3139   BIC:                                     -5986.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Fair or Poor Health")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.836
# Model:                            WLS   Adj. R-squared (uncentered):              0.836
# Method:                 Least Squares   F-statistic:                              3996.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:38   Log-Likelihood:                          3005.2
# No. Observations:                3142   AIC:                                     -6002.
# Df Residuals:                    3138   BIC:                                     -5978.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Enrolled in Free or Reduced Lunch")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.836
# Model:                            WLS   Adj. R-squared (uncentered):              0.836
# Method:                 Least Squares   F-statistic:                              3198.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:38   Log-Likelihood:                          3006.0
# No. Observations:                3142   AIC:                                     -6002.
# Df Residuals:                    3137   BIC:                                     -5972.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Physically Inactive")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.837
# Model:                            WLS   Adj. R-squared (uncentered):              0.837
# Method:                 Least Squares   F-statistic:                              2682.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3015.0
# No. Observations:                3142   AIC:                                     -6018.
# Df Residuals:                    3136   BIC:                                     -5982.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Children in Single-Parent Households")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.838
# Model:                            WLS   Adj. R-squared (uncentered):              0.837
# Method:                 Least Squares   F-statistic:                              2308.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3020.7
# No. Observations:                3142   AIC:                                     -6027.
# Df Residuals:                    3135   BIC:                                     -5985.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Some College")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.838
# Model:                            WLS   Adj. R-squared (uncentered):              0.837
# Method:                 Least Squares   F-statistic:                              2023.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3023.5
# No. Observations:                3142   AIC:                                     -6031.
# Df Residuals:                    3134   BIC:                                     -5983.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Adults with Diabetes")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.839
# Model:                            WLS   Adj. R-squared (uncentered):              0.838
# Method:                 Least Squares   F-statistic:                              1812.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3033.8
# No. Observations:                3142   AIC:                                     -6050.
# Df Residuals:                    3133   BIC:                                     -5995.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Smokers")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.840
# Model:                            WLS   Adj. R-squared (uncentered):              0.839
# Method:                 Least Squares   F-statistic:                              1643.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3043.8
# No. Observations:                3142   AIC:                                     -6068.
# Df Residuals:                    3132   BIC:                                     -6007.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Food Insecure")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.840
# Model:                            WLS   Adj. R-squared (uncentered):              0.840
# Method:                 Least Squares   F-statistic:                              1497.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3047.0
# No. Observations:                3142   AIC:                                     -6072.
# Df Residuals:                    3131   BIC:                                     -6005.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Frequent Physical Distress")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.843
# Model:                            WLS   Adj. R-squared (uncentered):              0.843
# Method:                 Least Squares   F-statistic:                              1402.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3076.3
# No. Observations:                3142   AIC:                                     -6129.
# Df Residuals:                    3130   BIC:                                     -6056.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Uninsured")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.844
# Model:                            WLS   Adj. R-squared (uncentered):              0.844
# Method:                 Least Squares   F-statistic:                              1307.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3089.5
# No. Observations:                3142   AIC:                                     -6153.
# Df Residuals:                    3129   BIC:                                     -6074.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Black")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.845
# Model:                            WLS   Adj. R-squared (uncentered):              0.844
# Method:                 Least Squares   F-statistic:                              1214.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3090.0
# No. Observations:                3142   AIC:                                     -6152.
# Df Residuals:                    3128   BIC:                                     -6067.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Insufficient Sleep")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.845
# Model:                            WLS   Adj. R-squared (uncentered):              0.845
# Method:                 Least Squares   F-statistic:                              1140.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3098.9
# No. Observations:                3142   AIC:                                     -6168.
# Df Residuals:                    3127   BIC:                                     -6077.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Frequent Mental Distress")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.845
# Model:                            WLS   Adj. R-squared (uncentered):              0.845
# Method:                 Least Squares   F-statistic:                              1068.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3099.0
# No. Observations:                3142   AIC:                                     -6166.
# Df Residuals:                    3126   BIC:                                     -6069.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("Average Number of Physically Unhealthy Days")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.847
# Model:                            WLS   Adj. R-squared (uncentered):              0.846
# Method:                 Least Squares   F-statistic:                              1020.
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3118.2
# No. Observations:                3142   AIC:                                     -6202.
# Df Residuals:                    3125   BIC:                                     -6100.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Non-Hispanic White")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.848
# Model:                            WLS   Adj. R-squared (uncentered):              0.847
# Method:                 Least Squares   F-statistic:                              964.9
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:39   Log-Likelihood:                          3121.0
# No. Observations:                3142   AIC:                                     -6206.
# Df Residuals:                    3124   BIC:                                     -6097.
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Adults with Obesity")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.849
# Model:                            WLS   Adj. R-squared (uncentered):              0.848
# Method:                 Least Squares   F-statistic:                              922.1
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:40   Log-Likelihood:                          3133.0
# No. Observations:                3142   AIC:                                     -6228.
# Df Residuals:                    3123   BIC:                                     -6113.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("Social Association Rate")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.853
# Model:                            WLS   Adj. R-squared (uncentered):              0.852
# Method:                 Least Squares   F-statistic:                              903.5
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:40   Log-Likelihood:                          3174.8
# No. Observations:                3142   AIC:                                     -6310.
# Df Residuals:                    3122   BIC:                                     -6189.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Excessive Drinking")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.853
# Model:                            WLS   Adj. R-squared (uncentered):              0.852
# Method:                 Least Squares   F-statistic:                              861.8
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:40   Log-Likelihood:                          3177.2
# No. Observations:                3142   AIC:                                     -6312.
# Df Residuals:                    3121   BIC:                                     -6185.
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Asian")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.853
# Model:                            WLS   Adj. R-squared (uncentered):              0.852
# Method:                 Least Squares   F-statistic:                              822.4
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:40   Log-Likelihood:                          3177.2
# No. Observations:                3142   AIC:                                     -6310.
# Df Residuals:                    3120   BIC:                                     -6177.
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Drive Alone to Work")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.853
# Model:                            WLS   Adj. R-squared (uncentered):              0.852
# Method:                 Least Squares   F-statistic:                              786.6
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:40   Log-Likelihood:                          3177.7
# No. Observations:                3142   AIC:                                     -6309.
# Df Residuals:                    3119   BIC:                                     -6170.
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Vaccinated")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.854
# Model:                            WLS   Adj. R-squared (uncentered):              0.853
# Method:                 Least Squares   F-statistic:                              758.5
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:40   Log-Likelihood:                          3186.3
# No. Observations:                3142   AIC:                                     -6325.
# Df Residuals:                    3118   BIC:                                     -6179.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("Average Number of Mentally Unhealthy Days")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.854
# Model:                            WLS   Adj. R-squared (uncentered):              0.853
# Method:                 Least Squares   F-statistic:                              728.0
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:40   Log-Likelihood:                          3186.5
# No. Observations:                3142   AIC:                                     -6323.
# Df Residuals:                    3117   BIC:                                     -6172.
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("per_gop")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.855
# Model:                            WLS   Adj. R-squared (uncentered):              0.853
# Method:                 Least Squares   F-statistic:                              704.3
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:40   Log-Likelihood:                          3195.1
# No. Observations:                3142   AIC:                                     -6338.
# Df Residuals:                    3116   BIC:                                     -6181.
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Less Than 18 Years of Age")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.855
# Model:                            WLS   Adj. R-squared (uncentered):              0.853
# Method:                 Least Squares   F-statistic:                              678.0
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:41   Log-Likelihood:                          3195.2
# No. Observations:                3142   AIC:                                     -6336.
# Df Residuals:                    3115   BIC:                                     -6173.
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Rural")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.855
# Model:                            WLS   Adj. R-squared (uncentered):              0.853
# Method:                 Least Squares   F-statistic:                              654.5
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:41   Log-Likelihood:                          3196.9
# No. Observations:                3142   AIC:                                     -6338.
# Df Residuals:                    3114   BIC:                                     -6168.
# Df Model:                          28
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Hispanic")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.855
# Model:                            WLS   Adj. R-squared (uncentered):              0.853
# Method:                 Least Squares   F-statistic:                              631.8
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:41   Log-Likelihood:                          3197.1
# No. Observations:                3142   AIC:                                     -6336.
# Df Residuals:                    3113   BIC:                                     -6161.
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
xcolumns.append("% Limited Access to Healthy Foods")
y=cleanerdf["deaths by county"]
x=cleanerdf[xcolumns]
get_stats()
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:       deaths by county   R-squared (uncentered):                   0.855
# Model:                            WLS   Adj. R-squared (uncentered):              0.853
# Method:                 Least Squares   F-statistic:                              610.7
# Date:                Sun, 04 Jul 2021   Prob (F-statistic):                        0.00
# Time:                        14:24:41   Log-Likelihood:                          3197.5
# No. Observations:                3142   AIC:                                     -6335.
# Df Residuals:                    3112   BIC:                                     -6153.
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x=cleanerdf[xcolumns]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30)
model=LinearRegression()
model.fit(x_train,y_train)

#creating my model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = model.predict(x_test)
plt.scatter(y_test, predictions)

#visualizing my model

# %%
plt.hist(y_test - predictions)
# Out:
# (array([  7.,  42., 257., 378., 171.,  60.,  13.,   8.,   4.,   3.]),
#  array([-0.26718125, -0.19178818, -0.11639511, -0.04100204,  0.03439103,
#          0.10978409,  0.18517716,  0.26057023,  0.3359633 ,  0.41135637,
#          0.48674944]),
#  <a list of 10 Patch objects>)

# %%
from sklearn import metrics

# %%
from sklearn.metrics import r2_score


metrics.r2_score(y_test, predictions)


#testing the performance of my model
# Out:
# 0.4090871755530142

# %%
from sklearn.metrics import max_error
max_error(y_test, predictions)
#testing the performance of my model
# Out:
# 0.4867494405243499

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, predictions)
#testing the performance of my model
# Out:
# 0.007781673747528622
